# %% [markdown]
# Autor:
# Manuel Eugenio Morocho Cayamcela, PhD

# %% [markdown]
# # **Prueba práctica 1 (Resolución):**
# ## Extracción de Patrones con los datos de California Housing Prices

# %% [markdown]
# ### **Objetivo y alcance del trabajo:**

# %% [markdown]
# Esta prueba práctica se centra en el análisis exploratorio de datos y la visualización de un conjunto de datos de viviendas. El conjunto de datos contiene información sobre las características de las viviendas, como la ubicación geográfica, el tamaño, el número de habitaciones, el precio medio y la proximidad al océano.
#
# El objetivo principal de este notebook es entender las relaciones entre las diferentes características de las viviendas. Para ello, realizaremos una serie de tareas, incluyendo la limpieza de los datos, la transformación de variables categóricas en numéricas, el cálculo de correlaciones entre las variables y la visualización de estas correlaciones.
#
# Al final de este notebook, tendremos una mejor comprensión de cómo las diferentes características de las viviendas están relacionadas entre sí, lo que nos permitirá realizar análisis más detallados en el futuro.

# %% [markdown]
# El dataset 'california_housing_prices.csv' contiene información sobre los precios de viviendas en California. Las variables presentes en el dataset son las siguientes:
#
# 1. longitude: La longitud geográfica de la ubicación de la vivienda.
# 2. latitude: La latitud geográfica de la ubicación de la vivienda.
# 3. housing_median_age: La edad mediana de las viviendas en la ubicación.
# 4. total_rooms: El número total de habitaciones en la vivienda.
# 5. total_bedrooms: El número total de dormitorios en la vivienda.
# 6. population: La población total en la ubicación.
# 7. households: El número total de hogares en la ubicación.
# 8. median_income: El ingreso mediano de los hogares en la ubicación.
# 9. median_house_value: El valor mediano de las viviendas en la ubicación.
# 10. ocean_proximity: La proximidad de la vivienda al océano.
#
# El dataset contiene un total de 20,640 registros. Las variables tienen diferentes tipos de datos, siendo la mayoría variables numéricas (float64) y una variable categórica (object). Algunas variables tienen valores faltantes en el dataset.

# %% [markdown]
# ### **Fase I:** Carga y análisis exploratorio inicial de los datos

# %%
# %pip install pandas seaborn matplotlib ipywidgets pandas-profiling

# Importamos las librerías 'pandas' con alias 'pd' y 'seaborn' con alias 'sns'
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pandas in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (2.3.3)
# Requirement already satisfied: seaborn in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: ipywidgets in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (8.1.9)
# Requirement already satisfied: pandas-profiling in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (3.6.6)
# Requirement already satisfied: numpy>=1.22.4 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pandas) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: comm>=0.1.3 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipywidgets) (5.15.1)
# Requirement already satisfied: widgetsnbextension~=4.0.16 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipywidgets) (4.0.16)
# Requirement already satisfied: jupyterlab_widgets~=3.0.17 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipywidgets) (3.0.17)
# Requirement already satisfied: ydata-profiling in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pandas-profiling) (4.17.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.1)
# Requirement already satisfied: decorator in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (5.3.1)
# Requirement already satisfied: jedi>=0.16 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (2.21.0)
# Requirement already satisfied: stack-data in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.16.0)
# Requirement already satisfied: exceptiongroup in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: pexpect>4.3 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.2)
# Requirement already satisfied: pure-eval in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.13.1)
# Requirement already satisfied: pydantic>=2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (0.8.1)
# Requirement already satisfied: minify-html>=0.15.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (4.70.0)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=3 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.9.6)
# Requirement already satisfied: dacite>=1.8 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (3.0.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from numba<=0.61,>=0.56.0->ydata-profiling->pandas-profiling) (0.43.0)
# Requirement already satisfied: joblib>=0.14.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2026.7.22)
# Requirement already satisfied: patsy>=0.5.6 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.0.2)
# Requirement already satisfied: importlib_metadata>=3.6 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from typeguard<5,>=3->ydata-profiling->pandas-profiling) (8.7.1)
# Requirement already satisfied: attrs>=19.3.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (3.2.1)
# Requirement already satisfied: puremagic in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (1.30)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cargamos el conjunto de datos 'california_housing_prices.csv' en un DataFrame llamado 'housing'
housing = pd.read_csv('/Users/eugenio/Documents/ArtificialIntelligence/Datasets/california_housing_prices.csv')

# %%
# Utilizamos el método 'head()' para visualizar las primeras 15 filas del DataFrame
housing.head(15)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# 5     -122.25     37.85                52.0        919.0           213.0
# 6     -122.25     37.84                52.0       2535.0           489.0
# 7     -122.25     37.84                52.0       3104.0           687.0
# 8     -122.26     37.84                42.0       2555.0           665.0
# 9     -122.25     37.84                52.0       3549.0           707.0
# 10    -122.26     37.85                52.0       2202.0           434.0
# 11    -122.26     37.85                52.0       3503.0           752.0
# 12    -122.26     37.85                52.0       2491.0           474.0
# 13    -122.26     37.84                52.0        696.0           191.0
# 14    -122.26     37.85                52.0       2643.0           626.0
#
#     population  households  median_income  median_house_value ocean_proximity
# 0        322.0       126.0         8.3252            452600.0        NEAR BAY
# 1       2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2        496.0       177.0         7.2574            352100.0        NEAR BAY
# 3        558.0       219.0         5.6431            341300.0        NEAR BAY
# 4        565.0       259.0         3.8462            342200.0        NEAR BAY
# 5        413.0       193.0         4.0368            269700.0        NEAR BAY
# 6       1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7       1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8       1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9       1551.0       714.0         3.6912            261100.0        NEAR BAY
# 10       910.0       402.0         3.2031            281500.0        NEAR BAY
# 11      1504.0       734.0         3.2705            241800.0        NEAR BAY
# 12      1098.0       468.0         3.0750            213500.0        NEAR BAY
# 13       345.0       174.0         2.6736            191300.0        NEAR BAY
# 14      1212.0       620.0         1.9167            159200.0        NEAR BAY

# %%
# Utilizamos el método describe() para obtener estadísticas descriptivas del DataFrame
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
# Utilizamos el método info() para obtener información sobre el DataFrame
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ### **Fase II:** Visualización de los datos

# %%
# Utilizamos el método 'hist()' de 'pandas' para visualizar un histograma de todas las columnas del DataFrame
housing.hist(figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Usamos la librería 'seaborn' para visualizar un 'scatterplot' (gráfico de dispersión) de las columnas 'longitude' y 'latitude' de las viviendas en California (DataFrame 'housing')
sns.scatterplot(x='longitude', y='latitude', data=housing)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
# Usamos la librería 'seaborn' para visualizar un 'scatterplot' (gráfico de dispersión) de las columnas 'longitude' y 'latitude' de las viviendas en California (DataFrame 'housing')
# Usamos el parámetro de opacidad 'alpha' de 0.1. Esto significa que los puntos tendrán una opacidad del 10%. Esto es útil cuando tenemos muchos puntos y queremos visualizar la densidad
# Usamos el parámetro 'hue' para agregar una dimensión adicional a la trama al colorear los puntos de datos según la variable 'median_house_value'
sns.scatterplot(x='longitude', y='latitude', data=housing, alpha=0.1, hue='median_house_value')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
# Usamos la librería 'seaborn' para visualizar un 'scatterplot' (gráfico de dispersión) de las columnas 'longitude' y 'latitude' de las viviendas en California, con la intensidad del color representando la proximidad al océano
sns.scatterplot(x='longitude', y='latitude', data=housing, alpha=0.4, hue='ocean_proximity')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ### **Fase III:** Correlación y perfilado de datos

# %%
# Instala la librería 'ydata_profiling' (Pandas Profiling) en el ambiente de desarrollo
# %pip install ydata_profiling

# Importa la clase 'ProfileReport' desde 'ydata_profiling'
from ydata_profiling import ProfileReport

# Utiliza Pandas Profiler para generar un informe de perfilado de datos del DataFrame 'housing'
profile = ProfileReport(housing, title='Reporte Perfilamiento de Datos', explorative=True)
profile.to_notebook_iframe()
# Out:
# Requirement already satisfied: ydata_profiling in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (4.17.0)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (3.9.4)
# Requirement already satisfied: pydantic>=2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (2.0.2)
# Requirement already satisfied: minify-html>=0.15.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (4.70.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=3 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (1.9.6)
# Requirement already satisfied: dacite>=1.8 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from ydata_profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from imagehash==4.3.1->ydata_profiling) (1.6.0)
# Requirement already satisfied: pillow in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from imagehash==4.3.1->ydata_profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (6.5.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from numba<=0.61,>=0.56.0->ydata_profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata_profiling) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata_profiling) (2026.3)
# Requirement already satisfied: joblib>=0.14.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata_profiling) (2026.7.22)
# Requirement already satisfied: patsy>=0.5.6 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.2)
# Requirement already satisfied: importlib_metadata>=3.6 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from typeguard<5,>=3->ydata_profiling) (8.7.1)
# Requirement already satisfied: typing_extensions>=4.14.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from typeguard<5,>=3->ydata_profiling) (4.16.0)
# Requirement already satisfied: attrs>=19.3.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (3.2.1)
# Requirement already satisfied: puremagic in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (1.30)
# Requirement already satisfied: zipp>=3.20 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from importlib_metadata>=3.6->typeguard<5,>=3->ydata_profiling) (3.23.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pydantic>=2->ydata_profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pydantic>=2->ydata_profiling) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from pydantic>=2->ydata_profiling) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata_profiling) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# /Users/eugenio/Documents/ArtificialIntelligence/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 239.15it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-08-27 00:20:20.450466&quot; name=date&gt;&lt;title&gt;Reporte Perfilamiento de Datos&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %%
profile.to_file("reporte_perfilamiento_datos.html")  # Guarda el informe en un archivo HTML
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
