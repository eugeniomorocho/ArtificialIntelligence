# %% [markdown]
# Author:
# Manuel Eugenio Morocho Cayamcela, PhD
#
# # Tutorial para importar imágenes en OpenCV

# %% [markdown]
# 1. **Instalación de OpenCV**: Si aún no tienes instalado OpenCV, puedes hacerlo utilizando pip. Abre tu terminal y escribe el comando: `pip install opencv-python`

# %%
# %pip install opencv-python
# %pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 MB 35.9 MB/s  0:00:01m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 21.5 MB/s  0:00:00 eta 0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:━━━━━━━━━━━━━━━━━━━ 0/2 [numpy]
#       Successfully uninstalled numpy-2.3.3━━ 0/2 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [opencv-python]0m [opencv-python]
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-macosx_10_13_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp313-cp313-macosx_10_13_x86_64.whl.metadata (6.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 25.7 MB/s  0:00:00 eta 0:00:01
# Using cached contourpy-1.3.3-cp313-cp313-macosx_10_13_x86_64.whl (293 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...

# %% [markdown]
# 2. **Importar las bibliotecas necesarias**: Primero, necesitamos importar las bibliotecas que vamos a utilizar. En este caso, necesitamos `cv2` para OpenCV y `matplotlib` para visualizar la imagen.

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# 3. **Leer una imagen**: Utilizamos la función `cv2.imread` de OpenCV para leer una imagen. La imagen debe estar en el mismo directorio que tu notebook de Jupyter, o necesitas proporcionar la ruta completa a la imagen.

# %%
imgBGR = cv2.imread('/Users/eugenio/Documents/ArtificialIntelligence/Unit 6. Neural Models, Vision, and Foundation Models/6.3 Convolutional Neural Networks (CNN)/6.3.1 Image classification/gato.jpg')

# %% [markdown]
# 4. **Visualizar la imagen**: OpenCV lee las imágenes en formato **BGR**, pero Matplotlib visualiza las imágenes en formato **RGB**. Por lo tanto, antes de visualizar la imagen, debemos convertirla de **BGR** a **RGB** usando el método `cv2.cvtColor` de la librería `opencv-python`. El argumento `cv2.COLOR_BGR2RGB` le dice a `cvtColor` qué conversión realizar: en este caso, de **BGR** a **RGB**.

# %%
imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)
plt.imshow(imgRGB)
plt.show()

# %% [markdown]
# #### **Actividad**
#
# 1. Carga una imagen en formato BGR usando `cv2.imread` de OpenCV.
# 2. Convierte la imagen de formato BGR a RGB usando la función `cv2.cvtColor`.
# 3. Visualiza la imagen usando `plt.imshow()`
